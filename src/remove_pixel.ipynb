# %%
import remove_pixels
import load_mnist
import load_helpers
import matplotlib.pyplot as plt
import numpy as np

# %%
(training_data, test_data) = load_mnist.load_mnist(1)
# (training_images,) = training_data[0]
# matrix = np.reshape(training_images, (28, 28))
# plt.imshow(matrix, cmap='gray')
# plt.show()

# %%
image_with_removed_datapoints = remove_pixels.remove_datapoints((training_data, test_data), 50)

# %%
(new_training_data, new_test_data) = image_with_removed_datapoints
#(training_images,) = image_with_removed_datapoints[0]
matrix = np.reshape(new_training_data, (28, 28))
plt.imshow(matrix, cmap='gray')
plt.show()
